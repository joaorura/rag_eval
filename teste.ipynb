# %%
import pandas as pd

# %%
test1 = pd.read_csv('result_opennai_llama3_1.csv')
test2 = pd.read_csv('result_opennai_llama3_2_3b.csv')

# %%
test1['answer_correctness'].mean(), test2['answer_correctness'].mean()
# Out:
# (0.5483511834017117, 0.5422704442430922)

# %%
test1['answer_relevancy'].mean(), test2['answer_relevancy'].mean()
# Out:
# (0.3820867370130023, 0.7222285836409187)

# %%
test1['answer_similarity'].mean(), test2['answer_similarity'].mean()
# Out:
# (0.8361383850820044, 0.8205226666596357)

# %%
test1['context_precision'].mean(), test2['context_precision'].mean()
# Out:
# (0.6344537814626051, 0.8130841121014022)

# %%
test1['context_recall'].mean(), test2['context_recall'].mean()
# Out:
# (0.6633464394932284, 0.6701690821256038)

# %%
test1['context_utilization'].mean(), test2['context_utilization'].mean()
# Out:
# (0.697478991542437, 0.7227722771831685)

# %%
test1['context_entity_recall'].mean(), test2['context_entity_recall'].mean()
# Out:
# (0.046918767345354814, 0.05496480618013228)

# %%
test1['faithfulness'].mean(), test2['faithfulness'].mean()
# Out:
# (0.6951409996622764, 0.7132632170972507)
