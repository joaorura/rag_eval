# %%
from ragas import EvaluationDataset
import pandas as pd
import json

dataframe = pd.read_csv("testset_openai_teste.csv", index_col=0)

# %%
dataframe['eval_sample'].apply(lambda x: json.loads(x))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 dataframe['eval_sample'].apply(lambda x: json.loads(x))
#
# File c:\Users\jmess\miniconda3\envs\rag_test\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
dict = dataframe['eval_sample'].apply(lambda x: eval(x)).to_dict()

# %%
print(dict[0])
# Out:
# {'user_input': 'Qual é a importância de um tema na construção de um contexto significativo?', 'retrieved_contexts': None, 'reference_contexts': [''], 'response': None, 'multi_responses': None, 'reference': 'A importância de um tema na construção de um contexto significativo reside na sua capacidade de fornecer um foco e uma direção, ajudando a conectar ideias e a dar sentido à narrativa.', 'rubric': None}
